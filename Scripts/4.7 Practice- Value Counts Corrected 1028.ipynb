# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ## Import Datasets

# %%
## Import Orders Products Merged
df_ords_prods_merge=pd.read_pickle(r'/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/orders_products_merged.pkl')

# %%
## First Million Rows from Orders and Products Merged Dataset
df=df_ords_prods_merge[:1000000]

# %% [markdown]
# ## User Defined Function: Product Range Types

# %%
def price_label(row):
    if row['prices']<=5:
        return 'Low Range Product'
    elif row['prices']>5 and row['prices']<=15:
        return 'Mid Range Product'
    elif row['prices']>15:
        return'High Range Product'
    else: return 'Not enough data'

# %% [markdown]
# ## Apply User Defined Function

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/3m/qtt2ngkx7fsblysy8c_rhytr0000gp/T/ipykernel_8439/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df_ords_prods_merge['price_range'] = df_ords_prods_merge.apply(price_label, axis=1)

# %%
## Check the Value Counts
df['price_range'].value_counts()
# Out:
# price_range
# Mid Range Product    756450
# Low Range Product    243550
# Name: count, dtype: int64

# %%
## Check the Maximum Price Value
df['prices'].max()
# Out:
# 14.8

# %%
df_ords_prods_merge['price_range'].value_counts()
# Out:
# price_range
# Mid Range Product     21889009
# Low Range Product     10126339
# High Range Product      417682
# Name: count, dtype: int64

# %% [markdown]
# ## Check Headings

# %%
df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  order_dow  \
# 0             0   2539329        1             1          2
# 1             1   2398795        1             2          3
# 2             2    473747        1             3          3
# 3             3   2254736        1             4          4
# 4             4    431534        1             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# ## Drop Columns Not Needed

# %%
df.drop(columns=['Unnamed: 0_x','Unnamed: 0_y','_merge'], inplace=True)
# Out:
# /var/folders/3m/qtt2ngkx7fsblysy8c_rhytr0000gp/T/ipykernel_8439/285460417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Unnamed: 0_x','Unnamed: 0_y','_merge'], inplace=True)

# %%
df.head(20)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   2968173       15            15          1                  9
# 11   1870022       15            17          2                 16
# 12   1911383       15            18          2                 11
# ...

# %% [markdown]
# ## If Statements with LOC Function

# %%
## High Range Product
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# /var/folders/3m/qtt2ngkx7fsblysy8c_rhytr0000gp/T/ipykernel_8439/150985519.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %% [markdown]
# ## For Loops

# %%
for x in range(30,45):
    print("My age is %d" %(x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
df_ords_prods_merge['order_dow'].value_counts(dropna=False)
# Out:
# order_dow
# 0    6209410
# 1    5665604
# 6    4500101
# 2    4217610
# 5    4209334
# 3    3843929
# 4    3787042
# Name: count, dtype: int64

# %%
## For Loop For Busiest Day
result = []

for value in df_ords_prods_merge["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# ## Add New Column For Busiest Day

# %%
df_ords_prods_merge['busiest_day']=result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22436578
# Busiest day        6209410
# Least busy         3787042
# Name: count, dtype: int64

# %% [markdown]
# ## New For Loop: Busiest Days and Least Busiest Days

# %%
## For Loop For Busiest Day
result=[]

for value in df_ords_prods_merge["order_dow"]:
  if value in (0,1):
    result.append("Busiest days")
  elif value in (3,4):
    result.append("Least busy days")
  else:
    result.append("Regularly busy")

# %% [markdown]
# ## Add Column Busiest and Least Busiest Days

# %%
df_ords_prods_merge['2busiest_slowest_days']=result

# %%
## 2 Busiest and 2 Slowest Days of the Week
df_ords_prods_merge['2busiest_slowest_days'].value_counts(dropna=False)
# Out:
# 2busiest_slowest_days
# Regularly busy     12927045
# Busiest days       11875014
# Least busy days     7630971
# Name: count, dtype: int64

# %%
## Check headings for New Columns 
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  order_dow  \
# 0             0   2539329        1             1          2
# 1             1   2398795        1             2          3
# 2             2    473747        1             3          3
# 3             3   2254736        1             4          4
# 4             4    431534        1             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# This dataset looks good to go!

# %% [markdown]
# ## What are the Busiest and Least Busy Hours of the Day?

# %%
## Hours of the Day Value Counts
df_ords_prods_merge['order_hour_of_day'].value_counts().sort_values(ascending=False)
# Out:
# order_hour_of_day
# 10    2764288
# 11    2738483
# 14    2691448
# 15    2664420
# 13    2663169
# 12    2620719
# 16    2537358
# 9     2456591
# 17    2089385
# 8     1719888
# 18    1637858
# 19    1259335
# 20     976991
# 7      891900
# 21     796341
# 22     634715
# 23     402593
# 6      290763
# 0      218925
# 1      115780
# 5       88054
# 2       69429
# 4       53280
# 3       51317
# Name: count, dtype: int64

# %% [markdown]
# ## Busiest Periods of the Day

# %%
## Busiest Periods of the Day
result=[]
for value in df_ords_prods_merge['order_hour_of_day']:
    if value in (10,11,14,15,13,12,16,9):
        result.append('Most Orders')
    elif value in (17,8,18,19,20,7,21,22):
        result.append("Average Orders")
    else:
        result.append("Fewest Orders")

# %%
df_ords_prods_merge['Busiest_Period_Of_Day']=result

# %%
## Busiest Periods of the Day Value Counts
df_ords_prods_merge['Busiest_Period_Of_Day'].value_counts(dropna=False)
# Out:
# Busiest_Period_Of_Day
# Most Orders       21136476
# Average Orders    10006413
# Fewest Orders      1290141
# Name: count, dtype: int64

# %%
## Check Headers
df_ords_prods_merge.head(10)
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  order_dow  \
# 0             0   2539329        1             1          2
# 1             1   2398795        1             2          3
# 2             2    473747        1             3          3
# 3             3   2254736        1             4          4
# 4             4    431534        1             5          4
# 5             5   3367565        1             6          2
# 6             6    550135        1             7          1
# 7             7   3108588        1             8          1
# 8             8   2295261        1             9          1
# 9             9   2550362        1            10          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# ...

# %%
## Remove Not Needed Columns
df_ords_prods_merge.drop(columns=['_merge'], inplace=True)

# %%
## Check Headings 
df_ords_prods_merge.head(10)
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  order_dow  \
# 0             0   2539329        1             1          2
# 1             1   2398795        1             2          3
# 2             2    473747        1             3          3
# 3             3   2254736        1             4          4
# 4             4    431534        1             5          4
# 5             5   3367565        1             6          2
# 6             6    550135        1             7          1
# 7             7   3108588        1             8          1
# 8             8   2295261        1             9          1
# 9             9   2550362        1            10          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# ...

# %% [markdown]
# ## Export File to Prepared Data Folder

# %%
df_ords_prods_merge.to_pickle('/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/df_ords_prods_merge_cust_col.pkl')
