# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Orders Products Prior (Key Variable) and Orders Merged Dataset

# %%
orders_products_combined=pd.read_pickle(r'/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/orders_products_combined.pkl')
df_prods_cleaned=pd.read_csv(r'/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/prods_cleaned_Oct21.csv')

# %%
## See Headers
orders_products_combined.head(10)
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
# 5           1   2398795        1             2          3                  7
# 6           1   2398795        1             2          3                  7
# 7           1   2398795        1             2          3                  7
# 8           1   2398795        1             2          3                  7
# 9           1   2398795        1             2          3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# ...

# %%
## Drop Unnamed Column
orders_products_combined.drop(columns='_merge', inplace=True)

# %%
## Check Column Headers
orders_products_combined.head(10)
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
# 5           1   2398795        1             2          3                  7
# 6           1   2398795        1             2          3                  7
# 7           1   2398795        1             2          3                  7
# 8           1   2398795        1             2          3                  7
# 9           1   2398795        1             2          3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# ...

# %% [markdown]
# ## Merge Orders Products Combined (Key Variable and Orders) Dataset with Products Dataset

# %%
df_orderswithkeyvariable=orders_products_combined.merge(df_prods_cleaned, on='product_id', indicator=True)

# %%
## Check Results of Merge Flag
df_orderswithkeyvariable.value_counts()
# Out:
# Unnamed: 0_x  order_id  user_id  order_number  order_dow  order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  reordered  Unnamed: 0_y  product_name                              aisle_id  department_id  prices  _merge
# 1             2398795   1        2             3          7                  15.0                    196         1                  1          195           Soda                                      77        7              9.0     both      1
# 2281414       3258452   137403   6             4          17                 30.0                    8518        3                  1          8518          Organic Red Onion                         83        4              6.3     both      1
# 2281413       2205955   137403   5             0          13                 30.0                    21927       3                  1          21928         Organic Boneless Skinless Chicken Breast  35        12             8.7     both      1
# ...

# %% [markdown]
# ## Export Orders_Products_Combined and Products Merged File

# %%
df_orderswithkeyvariable.to_pickle('/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/orders_products_merged.pkl')
