# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
## Import Dataframe

# %%
df_ords=pd.read_csv(r'/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/ords_cleaned_Oct21.csv')
df_prods=pd.read_csv(r'/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/prods_cleaned_Oct21.csv')
df_orders_products_prior=pd.read_csv(r'/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/orders_products_prior.csv')

# %% [markdown]
# ## Assess DF Prods Structure

# %%
df_prods.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49683       49688       49684
# 49684       49689       49685
# 49685       49690       49686
# 49686       49691       49687
# 49687       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49683          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
## Check df_prods Headings
df_prods.head(10)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
# 5           6                                       Dry Nose Oil        11
# 6           7                     Pure Coconut Water With Orange        98
# 7           8                  Cut Russet Potatoes Steam N' Mash       116
# 8           9                  Light Strawberry Blueberry Yogurt       120
# 9          10     Sparkling Orange Juice & Prickly Pear Beverage       115
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# ...

# %% [markdown]
# ### Analyze Shape and Columns of Data (Orders Products Prior)

# %%
df_orders_products_prior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  int64
#  3   reordered          int64
# dtypes: int64(4)
# memory usage: 989.8 MB

# %%
df_orders_products_prior.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0
# 5         2       17794                  6          1
# 6         2       40141                  7          1
# 7         2        1819                  8          1
# 8         2       43668                  9          0
# 9         3       33754                  1          1

# %% [markdown]
# ## Ords Data Columns and Structure

# %%
## Number of Rows
df_ords.info
# Out:
# <bound method DataFrame.info of          Unnamed: 0  order_id  user_id  order_number  order_dow  \
# 0                 0   2539329        1             1          2
# 1                 1   2398795        1             2          3
# 2                 2    473747        1             3          3
# 3                 3   2254736        1             4          4
# 4                 4    431534        1             5          4
# ...             ...       ...      ...           ...        ...
# 3421078     3421078   2266710   206209            10          5
# 3421079     3421079   1854736   206209            11          4
# 3421080     3421080    626363   206209            12          1
# 3421081     3421081   2977660   206209            13          1
# 3421082     3421082    272231   206209            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# ...

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           1   2398795        1             2          3                  7
# 2           2    473747        1             3          3                 12
# 3           3   2254736        1             4          4                  7
# 4           4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   order_id                int64
#  2   user_id                 int64
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(6)
# memory usage: 182.7 MB

# %% [markdown]
# ## Merge Orders and Products Datasets

# %%
df_merged_orders_ords_prods_prior = df_ords.merge(df_orders_products_prior, on = 'order_id', indicator = True)

# %%
## Check Merged Dataset Headings
df_merged_orders_ords_prods_prior.head(10)
# Out:
#    Unnamed: 0  order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0           0   2539329        1             1          2                  8
# 1           0   2539329        1             1          2                  8
# 2           0   2539329        1             1          2                  8
# 3           0   2539329        1             1          2                  8
# 4           0   2539329        1             1          2                  8
# 5           1   2398795        1             2          3                  7
# 6           1   2398795        1             2          3                  7
# 7           1   2398795        1             2          3                  7
# 8           1   2398795        1             2          3                  7
# 9           1   2398795        1             2          3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# ...

# %%
## Checked Merged Dataset Number of Rows
df_merged_orders_ords_prods_prior.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32434489 entries, 0 to 32434488
# Data columns (total 11 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0              int64
#  1   order_id                int64
#  2   user_id                 int64
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
#  7   product_id              int64
#  8   add_to_cart_order       int64
#  9   reordered               int64
#  10  _merge                  category
# dtypes: category(1), float64(1), int64(9)
# memory usage: 2.4 GB

# %% [markdown]
# ## Export Dataset

# %%
df_merged_orders_ords_prods_prior.to_pickle(r'/Users/sportsfan922/Documents/InstacartBasketAnalysis1025/Prepared Data/orders_products_combined.pkl')
